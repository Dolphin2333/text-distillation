# %%
# source /scratch/zz3645/miniforge/etc/profile.d/conda.sh
# conda activate base
# squeue -u $USER

# %%
import h5py
import torch

for f in [
    "out_step2_mrpc_emb_text_mlp_ipc5_s0.h5",
    "out_step2_mrpc_emb_text_mlp_ipc10_s1.h5",
    "out_step2_mrpc_emb_text_mlp_ipc15_s2.h5"
]:
    print("\n====", f, "====")
    with h5py.File(f, "r") as h:
        print("data shape:", h["data"][:].shape)
        if "label" in h:
            print("label shape:", h["label"][:].shape)
            print("unique labels:", set(h["label"][:].tolist()))
        else:
            print("NO LABEL FOUND")
# Out:
# ==== out_step2_mrpc_emb_text_mlp_ipc5_s0.h5 ====
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       4 for f in [
#       5     "out_step2_mrpc_emb_text_mlp_ipc5_s0.h5",
#       6     "out_step2_mrpc_emb_text_mlp_ipc10_s1.h5",
#       7     "out_step2_mrpc_emb_text_mlp_ipc15_s2.h5"
#       8 ]:
#       9     print("\n====", f, "====")
# ---> 10     with h5py.File(f, "r") as h:
#      11         print("data shape:", h["data"][:].shape)
#      12         if "label" in h:
#
# ...
